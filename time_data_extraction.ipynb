# %%
import requests
import pandas as pd
import time
from datetime import datetime, timedelta
from itertools import permutations
import os

def fetch_intraday_forex_data(api_key, date, ticker, timespan="minute", multiplier=1, max_retries=3):
    url = f"https://api.polygon.io/v2/aggs/ticker/{ticker}/range/{multiplier}/{timespan}/{date}/{date}"
    
    params = {
        "adjusted": "true",
        "sort": "asc",
        "limit": 50000,
        "apiKey": api_key
    }

    retries = 0
    while retries <= max_retries:
        try:
            response = requests.get(url, params=params)
            if response.status_code == 429:
                print(f"Rate limit hit for {ticker} on {date}. Sleeping 60 seconds...")
                time.sleep(60)
                retries += 1
                continue
            elif response.status_code != 200:
                print(f"Error {response.status_code} for {ticker} on {date}: {response.text}")
                return None

            data = response.json()
            if 'results' not in data or not data['results']:
                print(f"No results for {ticker} on {date}")
                return None

            return pd.DataFrame([{
                "date": date,
                "pair": ticker[2:],
                "timestamp": pd.to_datetime(r['t'], unit='ms'),
                "open": r.get("o", 0),
                "high": r.get("h", 0),
                "low": r.get("l", 0),
                "close": r.get("c", 0),
                "volume": r.get("v", 0)
            } for r in data["results"]])

        except requests.exceptions.RequestException as e:
            print(f"Network error for {ticker} on {date}: {e}")
            time.sleep(60)
            retries += 1

    print(f"Failed to fetch data for {ticker} on {date} after {max_retries} retries.")
    return None

API_KEY = "vSmtvpdrv8xGtZG7YYgSiPg3irGrpWbd"
currencies = ["USD", "EUR", "JPY", "GBP", "CNH", "AUD", "CAD", "CHF", "HKD", "SGD"]
currency_pairs = [f"C:{a}{b}" for a, b in permutations(currencies, 2)]

start_date = datetime(2025, 1, 1)
end_date = datetime(2025, 3, 30)

output_folder = "Data"
os.makedirs(output_folder, exist_ok=True)

current_date = start_date
while current_date <= end_date:
    date_str = current_date.strftime('%Y-%m-%d')
    filename = os.path.join(output_folder, f"forex_intraday_{date_str}.csv")

    if os.path.exists(filename):
        print(f"File already exists for {date_str}, skipping...")
        current_date += timedelta(days=1)
        continue

    all_data = []
    print(f"\nFetching data for {date_str}...")

    for i, pair in enumerate(currency_pairs):
        print(f"[{i+1}/{len(currency_pairs)}] → {pair}")
        df = fetch_intraday_forex_data(API_KEY, date_str, pair)
        if df is not None:
            all_data.append(df)
        time.sleep(1.2)

    if all_data:
        final_df = pd.concat(all_data, ignore_index=True)
        filename = os.path.join(output_folder, f"forex_intraday_{date_str}.csv")
        final_df.to_csv(filename, index=False)
        print(f"Saved {len(final_df)} rows to {filename}")
    else:
        print("No data fetched for this day.")

    current_date += timedelta(days=1)
# Out:
# 📅 Fetching data for 2025-01-01...
# [1/90] → C:USDEUR
# [2/90] → C:USDJPY
# [3/90] → C:USDGBP
# [4/90] → C:USDCNH
# [5/90] → C:USDAUD
# [6/90] → C:USDCAD
# ⚠️ Rate limit hit for C:USDCAD on 2025-01-01. Sleeping 60 seconds...
# [7/90] → C:USDCHF
# [8/90] → C:USDHKD
# [9/90] → C:USDSGD
# [10/90] → C:EURUSD
# [11/90] → C:EURJPY
# [12/90] → C:EURGBP
# ⚠️ Rate limit hit for C:EURGBP on 2025-01-01. Sleeping 60 seconds...
# [13/90] → C:EURCNH
# [14/90] → C:EURAUD
# [15/90] → C:EURCAD
# [16/90] → C:EURCHF
# [17/90] → C:EURHKD
# ⚠️ Rate limit hit for C:EURHKD on 2025-01-01. Sleeping 60 seconds...
# [18/90] → C:EURSGD
# [19/90] → C:JPYUSD
# [20/90] → C:JPYEUR
# [21/90] → C:JPYGBP
# [22/90] → C:JPYCNH
# ⚠️ Rate limit hit for C:JPYCNH on 2025-01-01. Sleeping 60 seconds...
# ⚠️ No results for C:JPYCNH on 2025-01-01
# [23/90] → C:JPYAUD
# [24/90] → C:JPYCAD
# [25/90] → C:JPYCHF
# [26/90] → C:JPYHKD
# [27/90] → C:JPYSGD
# ⚠️ Rate limit hit for C:JPYSGD on 2025-01-01. Sleeping 60 seconds...
# ⚠️ No results for C:JPYSGD on 2025-01-01
# [28/90] → C:GBPUSD
# [29/90] → C:GBPEUR
# [30/90] → C:GBPJPY
# [31/90] → C:GBPCNH
# ⚠️ No results for C:GBPCNH on 2025-01-01
# [32/90] → C:GBPAUD
# ⚠️ Rate limit hit for C:GBPAUD on 2025-01-01. Sleeping 60 seconds...
# [33/90] → C:GBPCAD
# [34/90] → C:GBPCHF
# [35/90] → C:GBPHKD
# [36/90] → C:GBPSGD
# [37/90] → C:CNHUSD
# [38/90] → C:CNHEUR
# ⚠️ No results for C:CNHEUR on 2025-01-01
# [39/90] → C:CNHJPY
# [40/90] → C:CNHGBP
# ⚠️ No results for C:CNHGBP on 2025-01-01
# [41/90] → C:CNHAUD
# ⚠️ No results for C:CNHAUD on 2025-01-01
# [42/90] → C:CNHCAD
# ⚠️ Rate limit hit for C:CNHCAD on 2025-01-01. Sleeping 60 seconds...
# ⚠️ No results for C:CNHCAD on 2025-01-01
# [43/90] → C:CNHCHF
# ⚠️ No results for C:CNHCHF on 2025-01-01
# [44/90] → C:CNHHKD
# [45/90] → C:CNHSGD
# ⚠️ No results for C:CNHSGD on 2025-01-01
# [46/90] → C:AUDUSD
# [47/90] → C:AUDEUR
# ⚠️ Rate limit hit for C:AUDEUR on 2025-01-01. Sleeping 60 seconds...
# [48/90] → C:AUDJPY
# [49/90] → C:AUDGBP
# [50/90] → C:AUDCNH
# [51/90] → C:AUDCAD
# [52/90] → C:AUDCHF
# ⚠️ Rate limit hit for C:AUDCHF on 2025-01-01. Sleeping 60 seconds...
# ⚠️ Rate limit hit for C:AUDCHF on 2025-01-01. Sleeping 60 seconds...
# [53/90] → C:AUDHKD
# [54/90] → C:AUDSGD
# [55/90] → C:CADUSD
# [56/90] → C:CADEUR
# [57/90] → C:CADJPY
# ⚠️ Rate limit hit for C:CADJPY on 2025-01-01. Sleeping 60 seconds...
# [58/90] → C:CADGBP
# [59/90] → C:CADCNH
# ⚠️ No results for C:CADCNH on 2025-01-01
# [60/90] → C:CADAUD
# [61/90] → C:CADCHF
# [62/90] → C:CADHKD
# ⚠️ Rate limit hit for C:CADHKD on 2025-01-01. Sleeping 60 seconds...
# [63/90] → C:CADSGD
# [64/90] → C:CHFUSD
# [65/90] → C:CHFEUR
# [66/90] → C:CHFJPY
# [67/90] → C:CHFGBP
# [68/90] → C:CHFCNH
# ⚠️ No results for C:CHFCNH on 2025-01-01
# [69/90] → C:CHFAUD
# ⚠️ Rate limit hit for C:CHFAUD on 2025-01-01. Sleeping 60 seconds...
# [70/90] → C:CHFCAD
# [71/90] → C:CHFHKD
# [72/90] → C:CHFSGD
# [73/90] → C:HKDUSD
# [74/90] → C:HKDEUR
# ⚠️ Rate limit hit for C:HKDEUR on 2025-01-01. Sleeping 60 seconds...
# [75/90] → C:HKDJPY
# [76/90] → C:HKDGBP
# [77/90] → C:HKDCNH
# ⚠️ No results for C:HKDCNH on 2025-01-01
# [78/90] → C:HKDAUD
# [79/90] → C:HKDCAD
# ⚠️ Rate limit hit for C:HKDCAD on 2025-01-01. Sleeping 60 seconds...
# [80/90] → C:HKDCHF
# [81/90] → C:HKDSGD
# [82/90] → C:SGDUSD
# [83/90] → C:SGDEUR
# [84/90] → C:SGDJPY
# ⚠️ Rate limit hit for C:SGDJPY on 2025-01-01. Sleeping 60 seconds...
# [85/90] → C:SGDGBP
# [86/90] → C:SGDCNH
# ⚠️ No results for C:SGDCNH on 2025-01-01
# [87/90] → C:SGDAUD
# [88/90] → C:SGDCAD
# [89/90] → C:SGDCHF
# ⚠️ Rate limit hit for C:SGDCHF on 2025-01-01. Sleeping 60 seconds...
# [90/90] → C:SGDHKD
# ✅ Saved 12252 rows to forex_intraday_2025-01-01.csv
#
# 📅 Fetching data for 2025-01-02...
# [1/90] → C:USDEUR
# [2/90] → C:USDJPY
# [3/90] → C:USDGBP
# [4/90] → C:USDCNH
# [5/90] → C:USDAUD
# [6/90] → C:USDCAD
# [7/90] → C:USDCHF
# [8/90] → C:USDHKD
# ⚠️ Rate limit hit for C:USDHKD on 2025-01-02. Sleeping 60 seconds...
# [9/90] → C:USDSGD
# [10/90] → C:EURUSD
# [11/90] → C:EURJPY
# [12/90] → C:EURGBP
# [13/90] → C:EURCNH
# ⚠️ Rate limit hit for C:EURCNH on 2025-01-02. Sleeping 60 seconds...
# [14/90] → C:EURAUD
# [15/90] → C:EURCAD
# [16/90] → C:EURCHF
# [17/90] → C:EURHKD
# [18/90] → C:EURSGD
# ⚠️ Rate limit hit for C:EURSGD on 2025-01-02. Sleeping 60 seconds...
# [19/90] → C:JPYUSD
# [20/90] → C:JPYEUR
# [21/90] → C:JPYGBP
# [22/90] → C:JPYCNH
# ⚠️ No results for C:JPYCNH on 2025-01-02
# [23/90] → C:JPYAUD
# ⚠️ Rate limit hit for C:JPYAUD on 2025-01-02. Sleeping 60 seconds...
# [24/90] → C:JPYCAD
# [25/90] → C:JPYCHF
# [26/90] → C:JPYHKD
# [27/90] → C:JPYSGD
# ⚠️ No results for C:JPYSGD on 2025-01-02
# [28/90] → C:GBPUSD
# ⚠️ Rate limit hit for C:GBPUSD on 2025-01-02. Sleeping 60 seconds...
# [29/90] → C:GBPEUR
# [30/90] → C:GBPJPY
# [31/90] → C:GBPCNH
# [32/90] → C:GBPAUD
# [33/90] → C:GBPCAD
# ⚠️ Rate limit hit for C:GBPCAD on 2025-01-02. Sleeping 60 seconds...
# [34/90] → C:GBPCHF
# [35/90] → C:GBPHKD
# [36/90] → C:GBPSGD
# [37/90] → C:CNHUSD
# [38/90] → C:CNHEUR
# ⚠️ Rate limit hit for C:CNHEUR on 2025-01-02. Sleeping 60 seconds...
# ⚠️ No results for C:CNHEUR on 2025-01-02
# [39/90] → C:CNHJPY
# [40/90] → C:CNHGBP
# ⚠️ No results for C:CNHGBP on 2025-01-02
# [41/90] → C:CNHAUD
# ⚠️ No results for C:CNHAUD on 2025-01-02
# [42/90] → C:CNHCAD
# ⚠️ No results for C:CNHCAD on 2025-01-02
# [43/90] → C:CNHCHF
# ⚠️ Rate limit hit for C:CNHCHF on 2025-01-02. Sleeping 60 seconds...
# ⚠️ No results for C:CNHCHF on 2025-01-02
# [44/90] → C:CNHHKD
# [45/90] → C:CNHSGD
# ⚠️ No results for C:CNHSGD on 2025-01-02
# [46/90] → C:AUDUSD
# [47/90] → C:AUDEUR
# [48/90] → C:AUDJPY
# ⚠️ Rate limit hit for C:AUDJPY on 2025-01-02. Sleeping 60 seconds...
# [49/90] → C:AUDGBP
# [50/90] → C:AUDCNH
# [51/90] → C:AUDCAD
# [52/90] → C:AUDCHF
# [53/90] → C:AUDHKD
# ⚠️ Rate limit hit for C:AUDHKD on 2025-01-02. Sleeping 60 seconds...
# [54/90] → C:AUDSGD
# [55/90] → C:CADUSD
# [56/90] → C:CADEUR
# [57/90] → C:CADJPY
# [58/90] → C:CADGBP
# [59/90] → C:CADCNH
# ⚠️ Rate limit hit for C:CADCNH on 2025-01-02. Sleeping 60 seconds...
# ⚠️ No results for C:CADCNH on 2025-01-02
# [60/90] → C:CADAUD
# [61/90] → C:CADCHF
# [62/90] → C:CADHKD
# [63/90] → C:CADSGD
# [64/90] → C:CHFUSD
# ⚠️ Rate limit hit for C:CHFUSD on 2025-01-02. Sleeping 60 seconds...
# [65/90] → C:CHFEUR
# [66/90] → C:CHFJPY
# [67/90] → C:CHFGBP
# [68/90] → C:CHFCNH
# ⚠️ No results for C:CHFCNH on 2025-01-02
# [69/90] → C:CHFAUD
# ⚠️ Rate limit hit for C:CHFAUD on 2025-01-02. Sleeping 60 seconds...
# [70/90] → C:CHFCAD
# [71/90] → C:CHFHKD
# [72/90] → C:CHFSGD
# [73/90] → C:HKDUSD
# [74/90] → C:HKDEUR
# ⚠️ Rate limit hit for C:HKDEUR on 2025-01-02. Sleeping 60 seconds...
# [75/90] → C:HKDJPY
# [76/90] → C:HKDGBP
# [77/90] → C:HKDCNH
# ⚠️ No results for C:HKDCNH on 2025-01-02
# [78/90] → C:HKDAUD
# [79/90] → C:HKDCAD
# [80/90] → C:HKDCHF
# [81/90] → C:HKDSGD
# [82/90] → C:SGDUSD
# [83/90] → C:SGDEUR
# [84/90] → C:SGDJPY
# ⚠️ Rate limit hit for C:SGDJPY on 2025-01-02. Sleeping 60 seconds...
# [85/90] → C:SGDGBP
# [86/90] → C:SGDCNH
# ⚠️ No results for C:SGDCNH on 2025-01-02
# [87/90] → C:SGDAUD
# [88/90] → C:SGDCAD
# [89/90] → C:SGDCHF
# ⚠️ Rate limit hit for C:SGDCHF on 2025-01-02. Sleeping 60 seconds...
# [90/90] → C:SGDHKD
# ✅ Saved 111252 rows to forex_intraday_2025-01-02.csv
#
# 📅 Fetching data for 2025-01-03...
# [1/90] → C:USDEUR
# [2/90] → C:USDJPY
# [3/90] → C:USDGBP
# [4/90] → C:USDCNH
# ⚠️ Rate limit hit for C:USDCNH on 2025-01-03. Sleeping 60 seconds...
# [5/90] → C:USDAUD
# [6/90] → C:USDCAD
# [7/90] → C:USDCHF
# [8/90] → C:USDHKD
# [9/90] → C:USDSGD
# ⚠️ Rate limit hit for C:USDSGD on 2025-01-03. Sleeping 60 seconds...
# [10/90] → C:EURUSD
# [11/90] → C:EURJPY
# [12/90] → C:EURGBP
# [13/90] → C:EURCNH
# [14/90] → C:EURAUD
# [15/90] → C:EURCAD
# [16/90] → C:EURCHF
# [17/90] → C:EURHKD
# ⚠️ Rate limit hit for C:EURHKD on 2025-01-03. Sleeping 60 seconds...
# [18/90] → C:EURSGD
# [19/90] → C:JPYUSD
# [20/90] → C:JPYEUR
# [21/90] → C:JPYGBP
# [22/90] → C:JPYCNH
# ⚠️ Rate limit hit for C:JPYCNH on 2025-01-03. Sleeping 60 seconds...
# ⚠️ No results for C:JPYCNH on 2025-01-03
# [23/90] → C:JPYAUD
# [24/90] → C:JPYCAD
# [25/90] → C:JPYCHF
# [26/90] → C:JPYHKD
# [27/90] → C:JPYSGD
# ⚠️ Rate limit hit for C:JPYSGD on 2025-01-03. Sleeping 60 seconds...
# ⚠️ No results for C:JPYSGD on 2025-01-03
# [28/90] → C:GBPUSD
# [29/90] → C:GBPEUR
# [30/90] → C:GBPJPY
# [31/90] → C:GBPCNH
# [32/90] → C:GBPAUD
# ⚠️ Rate limit hit for C:GBPAUD on 2025-01-03. Sleeping 60 seconds...
# [33/90] → C:GBPCAD
# [34/90] → C:GBPCHF
# [35/90] → C:GBPHKD
# [36/90] → C:GBPSGD
# [37/90] → C:CNHUSD
# [38/90] → C:CNHEUR
# ⚠️ No results for C:CNHEUR on 2025-01-03
# [39/90] → C:CNHJPY
# [40/90] → C:CNHGBP
# ⚠️ No results for C:CNHGBP on 2025-01-03
# [41/90] → C:CNHAUD
# ⚠️ No results for C:CNHAUD on 2025-01-03
# [42/90] → C:CNHCAD
# ⚠️ Rate limit hit for C:CNHCAD on 2025-01-03. Sleeping 60 seconds...
# ⚠️ No results for C:CNHCAD on 2025-01-03
# [43/90] → C:CNHCHF
# ⚠️ No results for C:CNHCHF on 2025-01-03
# [44/90] → C:CNHHKD
# [45/90] → C:CNHSGD
# ⚠️ No results for C:CNHSGD on 2025-01-03
# [46/90] → C:AUDUSD
# [47/90] → C:AUDEUR
# ⚠️ Rate limit hit for C:AUDEUR on 2025-01-03. Sleeping 60 seconds...
# [48/90] → C:AUDJPY
# [49/90] → C:AUDGBP
# [50/90] → C:AUDCNH
# [51/90] → C:AUDCAD
# [52/90] → C:AUDCHF
# ⚠️ Rate limit hit for C:AUDCHF on 2025-01-03. Sleeping 60 seconds...
# [53/90] → C:AUDHKD
# [54/90] → C:AUDSGD
# [55/90] → C:CADUSD
# [56/90] → C:CADEUR
# [57/90] → C:CADJPY
# ⚠️ Rate limit hit for C:CADJPY on 2025-01-03. Sleeping 60 seconds...
# [58/90] → C:CADGBP
# [59/90] → C:CADCNH
# ⚠️ No results for C:CADCNH on 2025-01-03
# [60/90] → C:CADAUD
# [61/90] → C:CADCHF
# [62/90] → C:CADHKD
# ⚠️ Rate limit hit for C:CADHKD on 2025-01-03. Sleeping 60 seconds...
# [63/90] → C:CADSGD
# [64/90] → C:CHFUSD
# [65/90] → C:CHFEUR
# [66/90] → C:CHFJPY
# [67/90] → C:CHFGBP
# [68/90] → C:CHFCNH
# ⚠️ Rate limit hit for C:CHFCNH on 2025-01-03. Sleeping 60 seconds...
# ⚠️ No results for C:CHFCNH on 2025-01-03
# [69/90] → C:CHFAUD
# [70/90] → C:CHFCAD
# [71/90] → C:CHFHKD
# [72/90] → C:CHFSGD
# [73/90] → C:HKDUSD
# ⚠️ Rate limit hit for C:HKDUSD on 2025-01-03. Sleeping 60 seconds...
# [74/90] → C:HKDEUR
# [75/90] → C:HKDJPY
# [76/90] → C:HKDGBP
# [77/90] → C:HKDCNH
# ⚠️ No results for C:HKDCNH on 2025-01-03
# [78/90] → C:HKDAUD
# ⚠️ Rate limit hit for C:HKDAUD on 2025-01-03. Sleeping 60 seconds...
# [79/90] → C:HKDCAD
# [80/90] → C:HKDCHF
# [81/90] → C:HKDSGD
# [82/90] → C:SGDUSD
# [83/90] → C:SGDEUR
# ⚠️ Rate limit hit for C:SGDEUR on 2025-01-03. Sleeping 60 seconds...
# [84/90] → C:SGDJPY
# [85/90] → C:SGDGBP
# [86/90] → C:SGDCNH
# ⚠️ No results for C:SGDCNH on 2025-01-03
# [87/90] → C:SGDAUD
# [88/90] → C:SGDCAD
# [89/90] → C:SGDCHF
# [90/90] → C:SGDHKD
# ✅ Saved 102763 rows to forex_intraday_2025-01-03.csv
#
# 📅 Fetching data for 2025-01-04...
# [1/90] → C:USDEUR
# ⚠️ No results for C:USDEUR on 2025-01-04
# [2/90] → C:USDJPY
# ⚠️ No results for C:USDJPY on 2025-01-04
# [3/90] → C:USDGBP
# ⚠️ Rate limit hit for C:USDGBP on 2025-01-04. Sleeping 60 seconds...
# ⚠️ No results for C:USDGBP on 2025-01-04
# [4/90] → C:USDCNH
# ⚠️ No results for C:USDCNH on 2025-01-04
# [5/90] → C:USDAUD
# ⚠️ No results for C:USDAUD on 2025-01-04
# [6/90] → C:USDCAD
# ⚠️ No results for C:USDCAD on 2025-01-04
# [7/90] → C:USDCHF
# ⚠️ No results for C:USDCHF on 2025-01-04
# [8/90] → C:USDHKD
# ⚠️ Rate limit hit for C:USDHKD on 2025-01-04. Sleeping 60 seconds...
# ⚠️ No results for C:USDHKD on 2025-01-04
# [9/90] → C:USDSGD
# ⚠️ No results for C:USDSGD on 2025-01-04
# [10/90] → C:EURUSD
# ⚠️ No results for C:EURUSD on 2025-01-04
# [11/90] → C:EURJPY
# ⚠️ No results for C:EURJPY on 2025-01-04
# [12/90] → C:EURGBP
# ⚠️ No results for C:EURGBP on 2025-01-04
# [13/90] → C:EURCNH
# ⚠️ Rate limit hit for C:EURCNH on 2025-01-04. Sleeping 60 seconds...
# ⚠️ No results for C:EURCNH on 2025-01-04
# [14/90] → C:EURAUD
# ⚠️ No results for C:EURAUD on 2025-01-04
# [15/90] → C:EURCAD
# ⚠️ No results for C:EURCAD on 2025-01-04
# [16/90] → C:EURCHF
# ⚠️ No results for C:EURCHF on 2025-01-04
# [17/90] → C:EURHKD
# ⚠️ No results for C:EURHKD on 2025-01-04
# [18/90] → C:EURSGD
# ⚠️ Rate limit hit for C:EURSGD on 2025-01-04. Sleeping 60 seconds...
# ⚠️ No results for C:EURSGD on 2025-01-04
# [19/90] → C:JPYUSD
# ⚠️ No results for C:JPYUSD on 2025-01-04
# [20/90] → C:JPYEUR
# ⚠️ No results for C:JPYEUR on 2025-01-04
# [21/90] → C:JPYGBP
# ⚠️ No results for C:JPYGBP on 2025-01-04
# [22/90] → C:JPYCNH
# ⚠️ No results for C:JPYCNH on 2025-01-04
# [23/90] → C:JPYAUD
# ⚠️ Rate limit hit for C:JPYAUD on 2025-01-04. Sleeping 60 seconds...
# ⚠️ No results for C:JPYAUD on 2025-01-04
# [24/90] → C:JPYCAD
# ⚠️ No results for C:JPYCAD on 2025-01-04
# [25/90] → C:JPYCHF
# ⚠️ No results for C:JPYCHF on 2025-01-04
# [26/90] → C:JPYHKD
# ⚠️ No results for C:JPYHKD on 2025-01-04
# [27/90] → C:JPYSGD
# ⚠️ No results for C:JPYSGD on 2025-01-04
# [28/90] → C:GBPUSD
# ⚠️ No results for C:GBPUSD on 2025-01-04
# [29/90] → C:GBPEUR
# ⚠️ No results for C:GBPEUR on 2025-01-04
# [30/90] → C:GBPJPY
# ⚠️ No results for C:GBPJPY on 2025-01-04
# [31/90] → C:GBPCNH
# ⚠️ Rate limit hit for C:GBPCNH on 2025-01-04. Sleeping 60 seconds...
# ⚠️ No results for C:GBPCNH on 2025-01-04
# [32/90] → C:GBPAUD
# ⚠️ No results for C:GBPAUD on 2025-01-04
# [33/90] → C:GBPCAD
# ⚠️ No results for C:GBPCAD on 2025-01-04
# [34/90] → C:GBPCHF
# ⚠️ No results for C:GBPCHF on 2025-01-04
# [35/90] → C:GBPHKD
# ⚠️ No results for C:GBPHKD on 2025-01-04
# [36/90] → C:GBPSGD
# ⚠️ Rate limit hit for C:GBPSGD on 2025-01-04. Sleeping 60 seconds...
# ⚠️ No results for C:GBPSGD on 2025-01-04
# [37/90] → C:CNHUSD
# ⚠️ No results for C:CNHUSD on 2025-01-04
# [38/90] → C:CNHEUR
# ⚠️ No results for C:CNHEUR on 2025-01-04
# [39/90] → C:CNHJPY
# ⚠️ No results for C:CNHJPY on 2025-01-04
# [40/90] → C:CNHGBP
# ⚠️ No results for C:CNHGBP on 2025-01-04
# [41/90] → C:CNHAUD
# ⚠️ Rate limit hit for C:CNHAUD on 2025-01-04. Sleeping 60 seconds...
# ⚠️ No results for C:CNHAUD on 2025-01-04
# [42/90] → C:CNHCAD
# ⚠️ No results for C:CNHCAD on 2025-01-04
# [43/90] → C:CNHCHF
# ⚠️ No results for C:CNHCHF on 2025-01-04
# [44/90] → C:CNHHKD
# ⚠️ No results for C:CNHHKD on 2025-01-04
# [45/90] → C:CNHSGD
# ⚠️ No results for C:CNHSGD on 2025-01-04
# [46/90] → C:AUDUSD
# ⚠️ Rate limit hit for C:AUDUSD on 2025-01-04. Sleeping 60 seconds...
# ⚠️ No results for C:AUDUSD on 2025-01-04
# [47/90] → C:AUDEUR
# ⚠️ No results for C:AUDEUR on 2025-01-04
# [48/90] → C:AUDJPY
# ⚠️ No results for C:AUDJPY on 2025-01-04
# [49/90] → C:AUDGBP
# ⚠️ No results for C:AUDGBP on 2025-01-04
# [50/90] → C:AUDCNH
# ⚠️ No results for C:AUDCNH on 2025-01-04
# [51/90] → C:AUDCAD
# ⚠️ Rate limit hit for C:AUDCAD on 2025-01-04. Sleeping 60 seconds...
# ⚠️ No results for C:AUDCAD on 2025-01-04
# [52/90] → C:AUDCHF
# ⚠️ No results for C:AUDCHF on 2025-01-04
# [53/90] → C:AUDHKD
# ⚠️ No results for C:AUDHKD on 2025-01-04
# [54/90] → C:AUDSGD
# ⚠️ No results for C:AUDSGD on 2025-01-04
# [55/90] → C:CADUSD
# ⚠️ No results for C:CADUSD on 2025-01-04
# [56/90] → C:CADEUR
# ⚠️ No results for C:CADEUR on 2025-01-04
# [57/90] → C:CADJPY
# ⚠️ No results for C:CADJPY on 2025-01-04
# [58/90] → C:CADGBP
# ⚠️ No results for C:CADGBP on 2025-01-04
# [59/90] → C:CADCNH
# ⚠️ No results for C:CADCNH on 2025-01-04
# [60/90] → C:CADAUD
# ⚠️ No results for C:CADAUD on 2025-01-04
# [61/90] → C:CADCHF
# ⚠️ Rate limit hit for C:CADCHF on 2025-01-04. Sleeping 60 seconds...
# ⚠️ No results for C:CADCHF on 2025-01-04
# [62/90] → C:CADHKD
# ⚠️ No results for C:CADHKD on 2025-01-04
# [63/90] → C:CADSGD
# ⚠️ No results for C:CADSGD on 2025-01-04
# [64/90] → C:CHFUSD
# ⚠️ No results for C:CHFUSD on 2025-01-04
# [65/90] → C:CHFEUR
# ⚠️ No results for C:CHFEUR on 2025-01-04
# [66/90] → C:CHFJPY
# ⚠️ Rate limit hit for C:CHFJPY on 2025-01-04. Sleeping 60 seconds...
# ⚠️ No results for C:CHFJPY on 2025-01-04
# [67/90] → C:CHFGBP
# ⚠️ No results for C:CHFGBP on 2025-01-04
# [68/90] → C:CHFCNH
# ⚠️ No results for C:CHFCNH on 2025-01-04
# [69/90] → C:CHFAUD
# ⚠️ No results for C:CHFAUD on 2025-01-04
# [70/90] → C:CHFCAD
# ⚠️ No results for C:CHFCAD on 2025-01-04
# [71/90] → C:CHFHKD
# ⚠️ Rate limit hit for C:CHFHKD on 2025-01-04. Sleeping 60 seconds...
# ⚠️ No results for C:CHFHKD on 2025-01-04
# [72/90] → C:CHFSGD
# ⚠️ No results for C:CHFSGD on 2025-01-04
# [73/90] → C:HKDUSD
# ⚠️ No results for C:HKDUSD on 2025-01-04
# [74/90] → C:HKDEUR
# ⚠️ No results for C:HKDEUR on 2025-01-04
# [75/90] → C:HKDJPY
# ⚠️ No results for C:HKDJPY on 2025-01-04
# [76/90] → C:HKDGBP
# ⚠️ Rate limit hit for C:HKDGBP on 2025-01-04. Sleeping 60 seconds...
# ⚠️ No results for C:HKDGBP on 2025-01-04
# [77/90] → C:HKDCNH
# ⚠️ No results for C:HKDCNH on 2025-01-04
# [78/90] → C:HKDAUD
# ⚠️ No results for C:HKDAUD on 2025-01-04
# [79/90] → C:HKDCAD
# ⚠️ No results for C:HKDCAD on 2025-01-04
# [80/90] → C:HKDCHF
# ⚠️ No results for C:HKDCHF on 2025-01-04
# [81/90] → C:HKDSGD
# ⚠️ Rate limit hit for C:HKDSGD on 2025-01-04. Sleeping 60 seconds...
# ⚠️ No results for C:HKDSGD on 2025-01-04
# [82/90] → C:SGDUSD
# ⚠️ No results for C:SGDUSD on 2025-01-04
# [83/90] → C:SGDEUR
# ⚠️ No results for C:SGDEUR on 2025-01-04
# [84/90] → C:SGDJPY
# ⚠️ No results for C:SGDJPY on 2025-01-04
# [85/90] → C:SGDGBP
# ⚠️ No results for C:SGDGBP on 2025-01-04
# [86/90] → C:SGDCNH
# ⚠️ No results for C:SGDCNH on 2025-01-04
# [87/90] → C:SGDAUD
# ⚠️ No results for C:SGDAUD on 2025-01-04
# [88/90] → C:SGDCAD
# ⚠️ No results for C:SGDCAD on 2025-01-04
# [89/90] → C:SGDCHF
# ⚠️ No results for C:SGDCHF on 2025-01-04
# [90/90] → C:SGDHKD
# ⚠️ No results for C:SGDHKD on 2025-01-04
# ⚠️ No data fetched for this day.
#
# 📅 Fetching data for 2025-01-05...
# [1/90] → C:USDEUR
# ⚠️ Rate limit hit for C:USDEUR on 2025-01-05. Sleeping 60 seconds...
# [2/90] → C:USDJPY
# [3/90] → C:USDGBP
# [4/90] → C:USDCNH
# [5/90] → C:USDAUD
# [6/90] → C:USDCAD
# ⚠️ Rate limit hit for C:USDCAD on 2025-01-05. Sleeping 60 seconds...
# [7/90] → C:USDCHF
# [8/90] → C:USDHKD
# [9/90] → C:USDSGD
# [10/90] → C:EURUSD
# [11/90] → C:EURJPY
# ⚠️ Rate limit hit for C:EURJPY on 2025-01-05. Sleeping 60 seconds...
# [12/90] → C:EURGBP
# [13/90] → C:EURCNH
# [14/90] → C:EURAUD
# [15/90] → C:EURCAD
# [16/90] → C:EURCHF
# ⚠️ Rate limit hit for C:EURCHF on 2025-01-05. Sleeping 60 seconds...
# [17/90] → C:EURHKD
# [18/90] → C:EURSGD
# [19/90] → C:JPYUSD
# [20/90] → C:JPYEUR
# [21/90] → C:JPYGBP
# ⚠️ Rate limit hit for C:JPYGBP on 2025-01-05. Sleeping 60 seconds...
# [22/90] → C:JPYCNH
# ⚠️ No results for C:JPYCNH on 2025-01-05
# [23/90] → C:JPYAUD
# [24/90] → C:JPYCAD
# [25/90] → C:JPYCHF
# [26/90] → C:JPYHKD
# [27/90] → C:JPYSGD
# ⚠️ No results for C:JPYSGD on 2025-01-05
# [28/90] → C:GBPUSD
# ⚠️ Rate limit hit for C:GBPUSD on 2025-01-05. Sleeping 60 seconds...
# [29/90] → C:GBPEUR
# [30/90] → C:GBPJPY
# [31/90] → C:GBPCNH
# [32/90] → C:GBPAUD
# [33/90] → C:GBPCAD
# ⚠️ Rate limit hit for C:GBPCAD on 2025-01-05. Sleeping 60 seconds...
# [34/90] → C:GBPCHF
# [35/90] → C:GBPHKD
# [36/90] → C:GBPSGD
# [37/90] → C:CNHUSD
# [38/90] → C:CNHEUR
# ⚠️ Rate limit hit for C:CNHEUR on 2025-01-05. Sleeping 60 seconds...
# ⚠️ No results for C:CNHEUR on 2025-01-05
# [39/90] → C:CNHJPY
# [40/90] → C:CNHGBP
# ⚠️ No results for C:CNHGBP on 2025-01-05
# [41/90] → C:CNHAUD
# ⚠️ No results for C:CNHAUD on 2025-01-05
# [42/90] → C:CNHCAD
# ⚠️ No results for C:CNHCAD on 2025-01-05
# [43/90] → C:CNHCHF
# ⚠️ Rate limit hit for C:CNHCHF on 2025-01-05. Sleeping 60 seconds...
# ⚠️ No results for C:CNHCHF on 2025-01-05
# [44/90] → C:CNHHKD
# [45/90] → C:CNHSGD
# ⚠️ No results for C:CNHSGD on 2025-01-05
# [46/90] → C:AUDUSD
# [47/90] → C:AUDEUR
# [48/90] → C:AUDJPY
# ⚠️ Rate limit hit for C:AUDJPY on 2025-01-05. Sleeping 60 seconds...
# [49/90] → C:AUDGBP
# [50/90] → C:AUDCNH
# [51/90] → C:AUDCAD
# [52/90] → C:AUDCHF
# [53/90] → C:AUDHKD
# [54/90] → C:AUDSGD
# [55/90] → C:CADUSD
# [56/90] → C:CADEUR
# [57/90] → C:CADJPY
# [58/90] → C:CADGBP
# ⚠️ Rate limit hit for C:CADGBP on 2025-01-05. Sleeping 60 seconds...
# [59/90] → C:CADCNH
# ⚠️ No results for C:CADCNH on 2025-01-05
# [60/90] → C:CADAUD
# [61/90] → C:CADCHF
# [62/90] → C:CADHKD
# [63/90] → C:CADSGD
# ⚠️ Rate limit hit for C:CADSGD on 2025-01-05. Sleeping 60 seconds...
